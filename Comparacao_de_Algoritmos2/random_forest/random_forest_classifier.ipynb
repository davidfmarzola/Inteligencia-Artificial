# %% [markdown]
# **Treinando o modelo com as classes desbalanceadas**

# %%
import pickle

with open('../sample_data/balanced_labor.pkl','rb') as f:
  X_train, X_test, y_train, y_test = pickle.load(f)

# %%
from sklearn.ensemble import RandomForestClassifier
modelo = RandomForestClassifier(n_estimators = 100, max_features = 6, criterion = 'entropy', random_state = 0)
modelo.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_features=6, random_state=0)

# %%
previsoes = modelo.predict(X_test)

# %%
from yellowbrick.classifier import ConfusionMatrix
from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix(y_test, previsoes)
# Out:
# array([[ 38,   1,   0],
#        [  0, 707,   0],
#        [  0,   0,   9]], dtype=int64)

# %%
cm = ConfusionMatrix(modelo)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.9986754966887417

# %%
print(classification_report(y_test, previsoes))
# Out:
#                          precision    recall  f1-score   support
#
# compensated_hypothyroid       1.00      0.97      0.99        39
#                negative       1.00      1.00      1.00       707
#     primary_hypothyroid       1.00      1.00      1.00         9
#
#                accuracy                           1.00       755
#               macro avg       1.00      0.99      1.00       755
#            weighted avg       1.00      1.00      1.00       755
