# %%
import pickle
with open('../sample_data/balanced_labor.pkl','rb') as f:
  X_over, X_test, y_over, y_test = pickle.load(f)

# %%
from sklearn.naive_bayes import GaussianNB 

X_over.toarray() # converting to dense matrix

naiveBayes = GaussianNB()
naiveBayes.fit(X_over, y_over)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive - sga.pucminas.br\Documentos\git\Inteligencia-Artificial\Comparacao_de_Algoritmos2\naive_bayes\naive_bayes_classifier.ipynb Célula: 2 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/Comparacao_de_Algoritmos2/naive_bayes/naive_bayes_classifier.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> X_over.toarray()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/Comparacao_de_Algoritmos2/naive_bayes/naive_bayes_classifier.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> naiveBayes = GaussianNB()
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

previsao = naiveBayes.predict(X_test)
print(accuracy_score(y_test,previsao))
print(confusion_matrix(y_test, previsao))
print(classification_report(y_test, previsao))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive - sga.pucminas.br\Documentos\git\Inteligencia-Artificial\Comparacao_de_Algoritmos2\naive_bayes\naive_bayes_classifier.ipynb Célula: 2 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/Comparacao_de_Algoritmos2/naive_bayes/naive_bayes_classifier.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/Comparacao_de_Algoritmos2/naive_bayes/naive_bayes_classifier.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> naiveBayes = GaussianNB()
# ...
