# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets

dataframe = pd.read_csv('stroke.csv', sep = ';')
X = dataframe.iloc[:, 0:11].values # dados
y = dataframe.iloc[:,11].values # classe alvo

xcls0 = X[y==0]
xcls1 = X[y==1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\User\OneDrive - sga.pucminas.br\Documentos\git\Inteligencia-Artificial\K-Means\agrupamentokmeans.ipynb Célula: 1 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/K-Means/agrupamentokmeans.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> dataframe = pd.read_csv('stroke.csv', sep = ',')
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/K-Means/agrupamentokmeans.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> X = dataframe.iloc[:, 0:11].values # dados
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20sga.pucminas.br/Documentos/git/Inteligencia-Artificial/K-Means/agrupamentokmeans.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> y = dataframe.iloc[:,11].values # classe alvo
# ...

# %%
plt.scatter(xcls1[:,0], xcls1[:,1], color='r')
plt.scatter(xcls0[:,0], xcls0[:,1], color='b')
plt.show()
